# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

# %%
sick_df = pd.read_csv("COVID_cases.csv")
eco_ind_df = pd.read_csv("Eco_indicators.csv")

# %%
sick_df.plot(kind="line", x="Date", y="Daily increase in Cases", rot=45)
