# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from config import bls_api_key

# Set data range for all API calls
start_year = "2008"
end_year = "2020"

# %% [markdown]
# # Demographic unemployment rate Data Pull

# %%
# Pull gender, race, educational attainment, and age data from Bureau of Labor Statistics

url = "https://api.bls.gov/publicAPI/v2/timeseries/data/"
headers = {"content-type": "application/json"}

target_series = ["LNS14000000", 
                 "LNS14000001", 
                 "LNS14000002", 
                 "LNS14000003", 
                 "LNS14000006", 
                 "LNS14032183", 
                 "LNS14000009",
                 "LNS14027659", 
                 "LNS14027660", 
                 "LNS14027689",
                 "LNS14027662", 
                 "LNS14024887",
                 "LNS14000089", 
                 "LNS14000091",
                 "LNS14000093",
                 "LNS14024230",
                ]

start_year = "2008"
end_year = "2018"

parameters = json.dumps({"seriesid": target_series,
             "startyear": start_year,
             "endyear": end_year,
             "registrationkey": bls_api_key})

p = requests.post(url, data=parameters, headers=headers)

json_data = json.loads(p.text)

json_data

# %%
#fill fit year and month into columns
years = []
months = []

for data_point in np.arange(len(json_data["Results"]["series"][0]["data"])):
        years.append(json_data["Results"]["series"][0]["data"][data_point]["year"])
        months.append(json_data["Results"]["series"][0]["data"][data_point]["periodName"])

# %%
# Create DataFrame with place holders for unemployment categories

layoffs_df = pd.DataFrame({"years": years,
                           "months": months,
                           "LNS14000000":"", 
                           "LNS14000000":"", 
                           "LNS14000001":"", 
                           "LNS14000002":"", 
                           "LNS14000003":"", 
                           "LNS14000006":"", 
                           "LNS14032183":"", 
                           "LNS14000009":"",
                           "LNS14027659":"", 
                           "LNS14027660":"", 
                           "LNS14027689":"",
                           "LNS14027662":"", 
                           "LNS14024887":"",
                           "LNS14000089":"", 
                           "LNS14000091":"",
                           "LNS14000093":"",
                           "LNS14024230":""  
                          })
layoffs_df.set_index(["years", "months","years","months","LNS14000000","LNS14000000","LNS14000001","LNS14000002","LNS14000003","LNS14000006",
                       "LNS14032183","LNS14000009","LNS14027659","LNS14027660","LNS14027689","LNS14027662","LNS14024887",
                       "LNS14000089","LNS14000091","LNS14000093","LNS14024230"])
layoffs_df.head()

# %%
# Fills in values

for series in np.arange(len(json_data["Results"]["series"])):
    for data_point in np.arange(len(json_data["Results"]["series"][series]["data"])):
        layoffs_df.loc[data_point, json_data["Results"]["series"][series]["seriesID"]] =\
        json_data["Results"]["series"][series]["data"][data_point]["value"]
   
      
layoffs_df.head()

# %%
# Rename column labels

layoffs_df.rename(columns={"LNS14000000": "Unemployment Rate for 16yo and over",
                           "LNS14000001": "Unemployment Rate for Men 16yo and over",
                           "LNS14000002": "Unemployment Rate for Women 16yo and over",
                           "LNS14000003": "Unemployment Rate for White people 16yo and over",
                           "LNS14000006": "Unemployment Rate for African Americans 16yo and over",
                           "LNS14032183": "Unemployment Rate for Asian people 16yo and over",
                           "LNS14000009": "Unemployment Rate for Hispanic people 16yo and over",
                           "LNS14027659": "Unemployment Rate for 25yo and older with less than High School Diploma",
                           "LNS14027660": "Unemployment Rate for 25yo and older with High School Degree",
                           "LNS14027689": "Unemployment Rate for 25yo and older with some college",
                           "LNS14027662": "Unemployment Rate for 25yo and older with Bachelor's degree or higher",
                           "LNS14024887": "Unemployment Rate for 16-24yo",
                           "LNS14000089": "Unemployment Rate for 25-34yo",
                           "LNS14000091": "Unemployment Rate for 35-44yo",
                           "LNS14000093": "Unemployment Rate for 45-54yo",
                            "LNS14024230": "Unemployment Rate for 55yo and over"
                          },
                      inplace=True)
layoffs_df.head(24)

# %%
#Industy Data Pull
url = "https://api.bls.gov/publicAPI/v2/timeseries/data/"
headers = {"content-type": "application/json"}

target_series = ["CES0000000001",
                 "CES0500000001", 
                 "CES0600000001", 
                 "CES0700000001", 
                 "CES0800000001", 
                 "CES1000000001", 
                 "CES2000000001", 
                 "CES3000000001", 
                 "CES3100000001", 
                 "CES3200000001", 
                 "CES4000000001", 
                 "CES4142000001", 
                 "CES4200000001", 
                 "CES4300000001", 
                 "CES4422000001", 
                 "CES5000000001", 
                 "CES5500000001", 
                 "CES6000000001", 
                 "CES6500000001", 
                 "CES7000000001", 
                 "CES8000000001", 
                 "CES9000000001"
                ]
#start_year = "2008"
#end_year = "2020"

parameters = json.dumps({"seriesid": target_series,
             "startyear": start_year,
             "endyear": end_year,
             "registrationkey": bls_api_key})

p = requests.post(url, data=parameters, headers=headers)

json_data4 = json.loads(p.text)

json_data4
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 1589,
#  'message': [],
#  'Results': {'series': [{'seriesID': 'CES0000000001',
#     'data': [{'year': '2020',
#       'period': 'M03',
#       'periodName': 'March',
#       'latest': 'true',
#       'value': '151786',
#       'footnotes': [{'code': 'P', 'text': 'preliminary'}]},
#      {'year': '2020',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '152487',
#       'footnotes': [{'code': 'P', 'text': 'preliminary'}]},
#      {'year': '2020',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '152212',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '151998',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '151814',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '151553',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '151368',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '151160',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '150953',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '150759',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '150577',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '150492',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '150282',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '150135',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '150134',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '149865',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '149683',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '149549',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '149348',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '149268',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '149024',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '148888',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '148669',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '148391',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '148254',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '148078',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '147672',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '147551',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '147421',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '147196',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '146929',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '146911',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '146727',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '146512',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '146296',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '146141',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '145944',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '145815',
#       'footnotes': [{}]},
#      {'year': '2017',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '145627',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '145442',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '145212',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '145061',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '144916',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '144647',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '144512',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '144158',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '143891',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '143849',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '143662',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '143433',
#       'footnotes': [{}]},
#      {'year': '2016',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '143170',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '143097',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '142824',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '142587',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '142281',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '142126',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '142001',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '141699',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '141525',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '141194',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '140910',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '140839',
#       'footnotes': [{}]},
#      {'year': '2015',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '140568',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '140377',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '140109',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '139818',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '139566',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '139257',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '139069',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '138837',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '138511',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '138293',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '137968',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '137714',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '137548',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '137373',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '137304',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '137040',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '136815',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '136628',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '136386',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '136274',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '136093',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '135871',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '135680',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '135541',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '135263',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '135072',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '134833',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '134677',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '134518',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '134331',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '134159',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '134007',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '133934',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '133834',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '133752',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '133512',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '133250',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '132896',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '132694',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '132562',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '132358',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '132125',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '131999',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '131939',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '131703',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '131602',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '131288',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '131053',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '130841',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '130822',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '130750',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '130625',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '130357',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '130422',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '130427',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '130511',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '130650',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '130110',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '129879',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '129698',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '129790',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '129788',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '130057',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '130045',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '130244',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '130485',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '130668',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '131008',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '131475',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '131817',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '132512',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '133312',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '134055',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '134839',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '135545',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '136272',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '136753',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '137213',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '137491',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '137687',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '137858',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '138035',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '138275',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '138324',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '138403',
#       'footnotes': [{}]}]},
#    {'seriesID': 'CES0500000001',
#     'data': [{'year': '2020',
#       'period': 'M03',
#       'periodName': 'March',
#       'latest': 'true',
#       'value': '129027',
#       'footnotes': [{'code': 'P', 'text': 'preliminary'}]},
#      {'year': '2020',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '129740',
#       'footnotes': [{'code': 'P', 'text': 'preliminary'}]},
#      {'year': '2020',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '129498',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '129319',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '129155',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '128908',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '128718',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '128523',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '128366',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '128206',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '128026',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '127939',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '127754',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '127622',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '127628',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '127370',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '127197',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '127064',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '126859',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '126778',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '126562',
#       'footnotes': [{}]},
#      {'year': '2018',
#       'period': 'M06',
#       'periodName': 'June',
#       'value':

#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '21855',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '21901',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '21895',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '21832',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '21853',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '21833',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '21825',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '21814',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '21820',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '21843',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '21830',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '21835',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '21831',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '21815',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '21840',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '21864',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '21869',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '21870',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '21881',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '21869',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '21887',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '21883',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '21903',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '21925',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '21916',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '21913',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '21930',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '21911',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '21931',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '21943',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '21947',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '21946',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '21954',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '21971',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '21998',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '21983',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '22017',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '22049',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '22164',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '22129',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '22184',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '22192',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '22215',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '22258',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '22266',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '22287',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '22297',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '22247',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '22420',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '22569',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '22740',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '22996',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '22569',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '22518',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '22476',
#       'footnotes': [{}]},
#      {'year': '2010',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '22491',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '22482',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '22533',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '22524',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '22451',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '22537',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '22521',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '22576',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '22617',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '22677',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '22560',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '22576',
#       'footnotes': [{}]},
#      {'year': '2009',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '22579',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '22556',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '22560',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '22549',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '22537',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '22567',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '22568',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '22517',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '22483',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '22450',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '22443',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '22417',
#       'footnotes': [{}]},
#      {'year': '2008',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '22388',
#       'footnotes': [{}]}]}]}}

# %%
years = []
months = []

for data_point in np.arange(len(json_data4["Results"]["series"][0]["data"])):
        years.append(json_data4["Results"]["series"][0]["data"][data_point]["year"])
        months.append(json_data4["Results"]["series"][0]["data"][data_point]["periodName"])

# %%
# Create DataFrame with place holders for unemployment categories

industry_df = pd.DataFrame({"Years": years,
                           "Months": months,
                           "CES0000000001":"", 
                           "CES0500000001":"",
                           "CES0600000001":"", 
                           "CES0700000001":"",
                           "CES0800000001":"", 
                           "CES1000000001":"",
                           "CES2000000001":"",
                           "CES3000000001":"", 
                           "CES3100000001":"",
                           "CES3200000001":"",
                           "CES4000000001":"", 
                           "CES4142000001":"",
                           "CES4200000001":"",
                           "CES4300000001":"", 
                           "CES4422000001":"",
                           "CES5000000001":"",
                           "CES5500000001":"", 
                           "CES6000000001":"",
                           "CES6500000001":"",
                           "CES7000000001":"", 
                           "CES8000000001":"",
                           "CES9000000001":""
                          })
industry_df.set_index(["Years", "Months",
                      "CES0000000001",
                      "CES0500000001", 
                      "CES0600000001", 
                      "CES0700000001", 
                      "CES0800000001", 
                      "CES1000000001", 
                      "CES2000000001", 
                      "CES3000000001", 
                      "CES3100000001", 
                      "CES3200000001", 
                      "CES4000000001", 
                      "CES4142000001", 
                      "CES4200000001", 
                      "CES4300000001", 
                      "CES4422000001", 
                      "CES5000000001", 
                      "CES5500000001", 
                      "CES6000000001", 
                      "CES6500000001", 
                      "CES7000000001", 
                      "CES8000000001", 
                      "CES9000000001"
                     ])
industry_df.head()
# Out:
#   Years    Months CES0000000001 CES0500000001 CES0600000001 CES0700000001  \
# 0  2020     March
# 1  2020  February
# 2  2020   January
# 3  2019  December
# 4  2019  November
#
#   CES0800000001 CES1000000001 CES2000000001 CES3000000001  ... CES4200000001  \
# 0                                                          ...
# 1                                                          ...
# 2                                                          ...
# 3                                                          ...
# 4                                                          ...
#
#   CES4300000001 CES4422000001 CES5000000001 CES5500000001 CES6000000001  \
# 0
# 1
# 2
# 3
# 4
#
#   CES6500000001 CES7000000001 CES8000000001 CES9000000001
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 24 columns]

# %%
# Fills in values for Idustry data

for series4 in np.arange(len(json_data4["Results"]["series"])):
    for data_point4 in np.arange(len(json_data4["Results"]["series"][series4]["data"])):
        industry_df.loc[data_point4, json_data4["Results"]["series"][series4]["seriesID"]] =\
        json_data4["Results"]["series"][series4]["data"][data_point4]["value"]
        
industry_df.head(10) 
#industry_df= industry_df.iloc[:,2:-1].astype(float)
industry_df.dtypes
# Out:
# Years            object
# Months           object
# CES0000000001    object
# CES0500000001    object
# CES0600000001    object
# CES0700000001    object
# CES0800000001    object
# CES1000000001    object
# CES2000000001    object
# CES3000000001    object
# CES3100000001    object
# CES3200000001    object
# CES4000000001    object
# CES4142000001    object
# CES4200000001    object
# CES4300000001    object
# CES4422000001    object
# CES5000000001    object
# CES5500000001    object
# CES6000000001    object
# CES6500000001    object
# CES7000000001    object
# CES8000000001    object
# CES9000000001    object
# dtype: object

# %%
# Rename columns to make more informative
industry_df.rename(columns={"CES0000000001":"Total Non-Farm",
                           "CES0500000001":"Total Private",
                           "CES0600000001":"Goods Production", 
                           "CES0700000001":"Service Production",
                           "CES0800000001":"Private Service Production", 
                           "CES1000000001":"Mining and Lodging",
                           "CES2000000001":"Construction",
                           "CES3000000001":"Manufacturing", 
                           "CES3100000001":"Durable Goods",
                           "CES3200000001":"NonDurable Good",
                           "CES4000000001":"Trade, Transportation and Utilities", 
                           "CES4142000001":"WholeSale Trade",
                           "CES4200000001":"Retail Trade",
                           "CES4300000001":"Transportation and Warehousing", 
                           "CES4422000001":"Utilities",
                           "CES5000000001":"Information",
                           "CES5500000001":"Financial Activities", 
                           "CES6000000001":"Professional and Business Services",
                           "CES6500000001":"Education and Health Services",
                           "CES7000000001":"Leisure and Hospitality", 
                           "CES8000000001":"Other Services",
                           "CES9000000001":"Government"},
                 inplace=True)

industry_df['Total Non-Farm'] = pd.to_numeric(industry_df['Total Non-Farm'])
industry_df['Total Private'] = pd.to_numeric(industry_df['Total Private'])
industry_df['Goods Production'] = pd.to_numeric(industry_df['Goods Production'])
industry_df['Service Production'] = pd.to_numeric(industry_df['Service Production'])
industry_df['Private Service Production'] = pd.to_numeric(industry_df['Private Service Production'])
industry_df['Mining and Lodging'] = pd.to_numeric(industry_df['Mining and Lodging'])
industry_df['Construction'] = pd.to_numeric(industry_df['Construction'])
industry_df['Manufacturing'] = pd.to_numeric(industry_df['Manufacturing'])
industry_df['Durable Goods'] = pd.to_numeric(industry_df['Durable Goods'])
industry_df['NonDurable Good'] = pd.to_numeric(industry_df['NonDurable Good'])
industry_df['Trade, Transportation and Utilities'] = pd.to_numeric(industry_df['Trade, Transportation and Utilities'])
industry_df['WholeSale Trade'] = pd.to_numeric(industry_df['WholeSale Trade'])
industry_df['Retail Trade'] = pd.to_numeric(industry_df['Retail Trade'])
industry_df['Transportation and Warehousing'] = pd.to_numeric(industry_df['Transportation and Warehousing'])
industry_df['Utilities'] = pd.to_numeric(industry_df['Utilities'])
industry_df['Information'] = pd.to_numeric(industry_df['Information'])
industry_df['Financial Activities'] = pd.to_numeric(industry_df['Financial Activities'])
industry_df['Professional and Business Services'] = pd.to_numeric(industry_df['Professional and Business Services'])
industry_df['Education and Health Services'] = pd.to_numeric(industry_df['Education and Health Services'])
industry_df['Leisure and Hospitality'] = pd.to_numeric(industry_df['Leisure and Hospitality'])
industry_df['Other Services'] = pd.to_numeric(industry_df['Other Services'])
industry_df['Government'] = pd.to_numeric(industry_df['Government'])

#Consolidate categories for manageability
industry_df['NewValue'] = industry_df['Total Non-Farm'] + industry_df['Total Private']

industry_df.head(10)
#industry_df.dtypes
# Out:
#   Years     Months  Total Non-Farm  Total Private  Goods Production  \
# 0  2020      March          151786         129027             21152
# 1  2020   February          152487         129740             21206
# 2  2020    January          152212         129498             21149
# 3  2019   December          151998         129319             21136
# 4  2019   November          151814         129155             21131
# 5  2019    October          151553         128908             21086
# 6  2019  September          151368         128718             21106
# 7  2019     August          151160         128523             21087
# 8  2019       July          150953         128366             21085
# 9  2019       June          150759         128206             21076
#
#    Service Production  Private Service Production  Mining and Lodging  \
# 0              130634                      107875                 708
# 1              131281                      108534                 715
# 2              131063                      108349                 712
# 3              130862                      108183                 715
# 4              130683                      108024                 724
# 5              130467                      107822                 735
# 6              130262                      107612                 731
# 7              130073                      107436                 731
# 8              129868                      107281                 736
# 9              129683                      107130                 741
#
#    Construction  Manufacturing  ...  Transportation and Warehousing  \
# 0          7605          12839  ...                          5672.4
# 1          7634          12857  ...                          5677.3
# 2          7593          12844  ...                          5678.5
# 3          7555          12866  ...                          5655.9
# 4          7539          12868  ...                          5658.0
# 5          7541          12810  ...                          5635.4
# 6          7524          12851  ...                          5628.6
# 7          7508          12848  ...                          5618.1
# 8          7504          12845  ...                          5622.2
# 9          7497          12838  ...                          5622.7
#
#    Utilities  Information  Financial Activities  \
# 0      547.9         2899                  8853
# 1      547.1         2897                  8854
# 2      546.9         2894                  8823
# 3      547.9         2883                  8814
# 4      547.2         2874                  8804
# 5      546.2         2865                  8792
# 6      547.5         2866                  8771
# 7      548.9         2861                  8768
# 8      549.6         2862                  8753
# 9      550.5         2865                  8732
#
#    Professinoal and Business Services  Education and Health Services  \
# 0                               21507                          24523
# 1                               21559                          24599
# 2                               21523                          24534
# 3                               21503                          24465
# 4                               21481                          24436
# 5                               21444                          24363
# 6                               21402                          24323
# 7                               21377                          24262
# 8                               21337                          24204
# 9                               21294                          24131
#
#    Leisure and Hospitality  Other Services  Government  NewValue
# 0                    16393            5919       22759    280813
# 1                    16852            5943       22747    282227
# 2                    16808            5935       22714    281710
# 3                    16784            5925       22679    281317
# 4                    16744            5923       22659    280969
# 5                    16701            5907       22645    280461
# 6                    16631            5907       22650    280086
# 7                    16570            5910       22637    279683
# 8                    16528            5905       22587    279319
# 9                    16526            5896       22553    278965
#
# [10 rows x 25 columns]

# %%
grouped_industry = industry_df.groupby('Years').mean()
grouped_industry.head(13)
# Out:
#        Total Non-Farm  Total Private  Goods Production  Service Production  \
# Years
# 2008    137224.583333  114721.666667      21331.500000       115893.083333
# 2009    131288.833333  108736.083333      18559.166667       112729.666667
# 2010    130336.750000  107847.083333      17751.750000       112585.000000
# 2011    131921.666667  109828.833333      18045.250000       113876.416667
# 2020            8843.333333                        21529.666667
#
#        Education and Health Services  Leisure and Hospitality  Other Services  \
# Years
# 2008                    19228.416667             13440.666667     5514.916667
# 2009                    19627.666667             13073.583333     5366.000000
# 2010                    19972.583333             13041.916667     5330.750000
# 2011                    20321.833333             13351.833333     5360.666667
# 2012                    20769.166667             13770.416667     5430.166667
# 2013                    21084.500000             14255.333333     5483.000000
# 2014                    21436.000000             14690.583333     5566.583333
# 2015                    22025.000000             15153.833333     5621.416667
# 2016                    22640.083333             15656.583333     5690.166667
# 2017                    23189.416667             16052.750000     5768.833333
# 2018                    23636.166667             16298.916667     5830.583333
# 2019                    24175.416667             16581.083333     5892.833333
# 2020                    24552.000000             16684.333333     5932.333333
#
#          Government       NewValue
# Years
# 2008   22502.916667  251946.250000
# 2009   22552.750000  240024.916667
# 2010   22489.666667  238183.833333
# 2011   22092.833333  241750.500000
# 2012   21919.583333  246393.583333
# 2013   21847.250000  250864.083333
# 2014   21875.083333  255969.416667
# 2015   22027.000000  261581.500000
# 2016   22229.583333  266429.250000
# 2017   22348.250000  270830.083333
# 2018   22448.000000  275333.500000
# 2019   22588.416667  279282.416667
# 2020   22740.000000  281583.333333
#
# [13 rows x 23 columns]

# %%
#Create date feld to hold date for indexing
date = []

for index, row in education_df.iterrows():
    datenumber = str(f"{row['Year']}-{row['Month #']}")
    date.append(datenumber)

education_df['Date'] = date

education_df = education_df[['Year', 'Month #', 'Month', 'Date', 'No High School Diploma', 'High School Graduate',
                            'Some College', "Bachelor's Degree or Higher"]]
                     
education_df = education_df.reindex(index=education_df.index[::-1])
education_df.head()

# %%
plt.figure(figsize=(15,10))
Construction = plt.plot(grouped_industry['Years'], grouped_industry['Construction'], color='blue')
Manufacturing = plt.plot(grouped_industry['Years'], grouped_industry['Manufacturing'], color='red')
TradeTransportationUtilities = plt.plot(grouped_industry['Years'], grouped_industry['Trade, Transportation and Utilities'], color='green')
Information = plt.plot(grouped_industry['Years'], grouped_industry["Information"], color='purple')
Financial = plt.plot(grouped_industry['Years'], grouped_industry["Financial Activities"], color='yellow')
BusinessServices = plt.plot(grouped_industry['Years'], grouped_industry["Professional and Business Services"], color='orange')
EducationHealthServices = plt.plot(grouped_industry['Years'], grouped_industry["Education and Health Services"], color='black')
Hospitality = plt.plot(grouped_industry['Years'], grouped_industry["Leisure and Hospitality"], color='cyan')
OtherService = plt.plot(grouped_industry['Years'], grouped_industry["Other Services"], color='grey')
Government = plt.plot(grouped_industry['Years'], grouped_industry["Government"], color='brown')

red_glabel = mpatches.Patch(color='red', label='Construction')
blue_glabel = mpatches.Patch(color='blue', label='Manufacturing')
green_glabel = mpatches.Patch(color='green', label='TradeTransportationUtilities')
purple_glabel = mpatches.Patch(color='purple', label='Information')
yellow_glabel = mpatches.Patch(color='purple', label='Financial Activities')
orange_glabel = mpatches.Patch(color='red', label='BusinessServices')
black_glabel = mpatches.Patch(color='blue', label='EducationHealthServices')
cyan_glabel = mpatches.Patch(color='green', label='Hospitality')
grey_glabel = mpatches.Patch(color='purple', label='OtherService')
brown_glabel = mpatches.Patch(color='purple', label='Government')

plt.legend(handles=[blue_glabel, red_glabel, green_glabel, purple_glabel, yellow_glabel, orange_glabel,\
                   black_glabel, cyan_glable, grey_glabel, brown_glabel])
plt.title('Annual - Industry Employment levels by Major Sectors')
plt.ylabel('Average Annual Number of Person Employed in Sector')
plt.xlabel('Year')
plt.grid()
# set tick locations to the drug regimens
#tick_locations = [value for value in x_axis]

#plt.xticks(tick_locations,['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 
#                           'Placebo', 'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol'], rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9f8105b57dae> in <module>
# ----> 1 plt.figure(figsize=(15,10))
#       2 Construction = plt.plot(grouped_industry['Years'], grouped_industry['Construction'], color='blue')
#       3 Manufacturing = plt.plot(grouped_industry['Years'], grouped_industry['Manufacturing'], color='red')
#       4 TradeTransportationUtilities = plt.plot(grouped_industry['Years'], grouped_industry['Trade, Transportation and Utilities'], color='green')
#       5 Information = plt.plot(grouped_industry['Years'], grouped_industry["Information"], color='purple')
#
# NameError: name 'plt' is not defined

# %%
# creating DataFrame with Specific columns
yearinfo = education_df[['Year', 'No High School Diploma', 'High School Graduate', 'Some College', "Bachelor's Degree or Higher"]]

year_groupby= yearinfo.groupby('Year')['No High School Diploma', 'High School Graduate', 
                                       'Some College', "Bachelor's Degree or Higher"].mean()

year_groupby

# %%
year_groupby.plot.bar(rot=0, figsize=(15, 10))
plt.xlabel("Year")
plt.ylabel("Unemployment Rate (% Average)")
plt.title("Unemployment Impact on Different Levels of Education")

# %%
grouped_industry_T = grouped_industry.T
grouped_industry_T.head()
# Out:
# Years                                2008           2009           2010  \
# Total Non-Farm              137224.583333  131288.833333  130336.750000
# Total Private               114721.666667  108736.083333  107847.083333
# Goods Production             21331.500000   18559.166667   17751.750000
# Service Production          115893.083333  112729.666667  112585.000000
# Private Service Production   93390.166667   90176.916667   90095.333333
#
# Years                                2011           2012           2013  \
# Total Non-Farm              131921.666667  134156.583333  136355.666667
# Total Private               109828.833333  112237.000000  114508.416667
# Goods Production             18045.250000   18419.916667   18738.833333
# Service Production          113876.416667  115736.666667  117616.833333
# Private Service Production   91783.583333   93817.083333   95769.583333
#
# Years                                2014           2015           2016  \
# Total Non-Farm              138922.250000  141804.250000  144329.416667
# Total Private               117047.166667  119777.250000  122099.833333
# Goods Production             19225.833333   19607.583333   19747.750000
# Service Production          119696.416667  122196.666667  124581.666667
# Private Service Production   97821.333333  100169.666667  102352.083333
#
# Years                                2017           2018           2019  \
# Total Non-Farm              146589.166667  148890.750000  150935.416667
# Total Private               124240.916667  126442.750000  128347.000000
# Goods Production             20079.666667   20700.916667   21068.666667
# Service Production          126509.500000  128189.833333  129866.750000
# Private Service Production  104161.250000  105741.833333  107278.333333
#
# Years                                2020
# Total Non-Farm              152161.666667
# Total Private               129421.666667
# Goods Production             21169.000000
# Service Production          130992.666667
# Private Service Production  108252.666667

# %%
piechart_df = grouped_industry_T.loc[grouped_industry_T["2018"] == "Billy", :]
