# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# %%
pull_education_df = unemployment_df
len(pull_education_df)
# Out:
# 132

# %%
educationyears = df['Year'].unique()
educationmonthnumber = [ ]

for year in educationyears:
    educationmonth = 13
    while (educationmonth > 1): 
        educationmonth = educationmonth -1
        educationmonthnumber.append(educationmonth)
        if  educationmonth == 0:
            break
df['Month #'] = educationmonthnumber

# %%
education_df = pull_education_df[['Year', 'Month #', 'Month', 'Unemployment Rate for 25yo and older with less than High School Diploma',
                  'Unemployment Rate for 25yo and older with High School Degree', 
                  'Unemployment Rate for 25yo and older with some college',
                  "Unemployment Rate for 25yo and older with Bachelor's degree or higher"]]

education_df = education_df.rename(columns={'Unemployment Rate for 25yo and older with less than High School Diploma': "No High School Diploma",
                                           'Unemployment Rate for 25yo and older with High School Degree': 'High School Graduate',
                                           'Unemployment Rate for 25yo and older with some college': 'Some College',
                                           "Unemployment Rate for 25yo and older with Bachelor's degree or higher": "Bachelor's Degree or Higher"})
education_df.head()
# Out:
#    Year  Month #      Month  No High School Diploma  High School Graduate  \
# 0  2018       12   December                     5.8                   3.8
# 1  2018       11   November                     5.6                   3.5
# 2  2018       10    October                     5.9                   4.0
# 3  2018        9  September                     5.7                   3.8
# 4  2018        8     August                     5.7                   3.9
#
#    Some College  Bachelor's Degree or Higher
# 0           3.3                          2.2
# 1           3.1                          2.2
# 2           3.1                          2.0
# 3           3.2                          2.0
# 4           3.5                          2.0

# %%
educationdate = []

for index, row in education_df.iterrows():
    educationdatenumber = str(f"{row['Year']}-{row['Month #']}")
    educationdate.append(educationdatenumber)

education_df['Date'] = educationdatenumber

education_df = education_df[['Year', 'Month #', 'Month', 'Date', 'No High School Diploma', 'High School Graduate',
                            'Some College', "Bachelor's Degree or Higher"]]
                     
education_df = education_df.reindex(index=education_df.index[::-1])
education_df.head()
# Out:
#      Year  Month #     Month    Date  No High School Diploma  \
# 131  2008        1   January  2008-1                     7.7
# 130  2008        2  February  2008-2                     7.4
# 129  2008        3     March  2008-3                     8.4
# 128  2008        4     April  2008-4                     7.7
# 127  2008        5       May  2008-5                     8.1
#
#      High School Graduate  Some College  Bachelor's Degree or Higher
# 131                   4.7           3.7                          2.1
# 130                   4.7           3.8                          2.0
# 129                   5.1           3.9                          2.1
# 128                   5.0           4.0                          2.1
# 127                   5.0           4.3                          2.2

# %%
plt.figure(figsize=(15,10))
nohighschool = plt.plot(education_df['Date'], education_df['No High School Diploma'], color='blue')
highschool = plt.plot(education_df['Date'], education_df['High School Graduate'], color='red')
somecollege = plt.plot(education_df['Date'], education_df['Some College'], color='green')
college = plt.plot(education_df['Date'], education_df["Bachelor's Degree or Higher"], color='purple')
red_glabel = mpatches.Patch(color='red', label='High School Graduate')
blue_glabel = mpatches.Patch(color='blue', label='No High School Diploma')
green_glabel = mpatches.Patch(color='green', label='Some College')
purple_glabel = mpatches.Patch(color='purple', label="Bachelor's Degree or Higher")
plt.legend(handles=[blue_glabel, red_glabel, green_glabel, purple_glabel])
plt.title('Unemployment impact on Different Education Levels')
plt.ylabel('Unemployment Percentage (Monthly %)')
plt.xlabel('Date')
plt.grid()
plt.xticks(education_df['Date'][::12], rotation='vertical')
plt.show()

# %%
#send to plots notebook

# %%
bareducation_df = education_df
bareducation_df
# Out:
#      Year  Month #      Month     Date  No High School Diploma  \
# 131  2008        1    January   2008-1                     7.7
# 130  2008        2   February   2008-2                     7.4
# 129  2008        3      March   2008-3                     8.4
# 128  2008        4      April   2008-4                     7.7
# 127  2008        5        May   2008-5                     8.1
# ..    ...      ...        ...      ...                     ...
# 4    2018        8     August   2018-8                     5.7
# 3    2018        9  September   2018-9                     5.7
# 2    2018       10    October  2018-10                     5.9
# 1    2018       11   November  2018-11                     5.6
# 0    2018       12   December  2018-12                     5.8
#
#      High School Graduate  Some College  Bachelor's Degree or Higher
# 131                   4.7           3.7                          2.1
# 130                   4.7           3.8                          2.0
# 129                   5.1           3.9                          2.1
# 128                   5.0           4.0                          2.1
# 127                   5.0           4.3                          2.2
# ..                    ...           ...                          ...
# 4                     3.9           3.5                          2.0
# 3                     3.8           3.2                          2.0
# 2                     4.0           3.1                          2.0
# 1                     3.5           3.1                          2.2
# 0                     3.8           3.3                          2.2
#
# [132 rows x 8 columns]

# %%
educationyearinfo = education_df[['Year', 'No High School Diploma', 'High School Graduate', 'Some College', "Bachelor's Degree or Higher"]]

educationyear_groupby= educationyearinfo.groupby('Year')['No High School Diploma', 'High School Graduate', 
                                       'Some College', "Bachelor's Degree or Higher"].mean()

educationyear_groupby
# Out:
#       No High School Diploma  High School Graduate  Some College  \
# Year
# 2008                9.025000              5.683333      4.575000
# 2009               14.666667              9.733333      7.958333
# 2010               14.841667             10.291667      8.383333
# 2011               14.075000              9.425000      7.966667
# 2012               12.391667              8.308333      7.100000
# 2013               10.958333              7.508333      6.366667
# 2014                9.016667              6.008333      5.425000
# 2015                7.941667              5.441667      4.508333
# 2016                7.433333              5.191667      4.083333
# 2017                6.508333              4.650000      3.750000
# 2018                5.608333              4.041667      3.316667
#
#       Bachelor's Degree or Higher
# Year
# 2008                     2.558333
# 2009                     4.608333
# 2010                     4.708333
# 2011                     4.308333
# 2012                     4.025000
# 2013                     3.700000
# 2014                     3.175000
# 2015                     2.566667
# 2016                     2.508333
# 2017                     2.316667
# 2018                     2.125000

# %%
educationyear_groupby.plot.bar(rot=0, figsize=(15, 10))
plt.xlabel("Year")
plt.ylabel("Unemployment Rate (% Average)")
plt.title("Unemployment Impact on Different Levels of Education")
# Out:
# Text(0.5, 1.0, 'Unemployment Impact on Different Levels of Education')

# %%
#send to plots notebook
